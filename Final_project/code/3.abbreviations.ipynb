# %%
# from google.colab import drive
# drive.mount("/content/drive")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import os
import math

# %% [markdown]
# # Load data

# %%
# %pwd
# Out:
# 'd:\\UIT\\Nam3_ky2\\ML\\CS114\\Final_project\\code'

# %%
# path = "/content/drive/MyDrive/ML/Final_Project/1. data_raw/"
# data = pd.DataFrame()
# for file in os.listdir(path):
#     df = pd.read_excel(path+file)
#     data = pd.concat([data, df])

df1 = pd.read_excel("../dataset/raw_data/negative_data.xlsx")
df2 = pd.read_excel("../dataset/raw_data/neutral_data.xlsx")
df3 = pd.read_excel("../dataset/raw_data/positive_data.xlsx")
data = pd.DataFrame()
data = pd.concat([data, df1, df2, df3])

# %%
data
# Out:
#      Rate                                             Review  Label
# 0     4.0  Mình thề là mình ko thể cảm nổi đồ ăn ở aeon m...     -1
# 1     3.8  Đôi khi thèm lên là bất chấp nắng nóng phi Và ...     -1
# 2     3.8  Ngõ treo biển cafe trứng đúng kiểu phố cổ hà n...     -1
# 3     3.8  Mình thấy địa chỉ cafe Giảng ở Nguyễn Hữu Huân...     -1
# 4     2.2  Mình là người Hà Nội và cũng cực kỳ khó tính t...     -1
# ...   ...                                                ...    ...
# 6904  9.0  Mình là khách hàng thường xuyên của quán, có t...      1
# 6905  7.2  Mình mới đến quán 1 lần và cảm thấy quán khá d...      1
# 6906  8.0  Quán ăn đồ Hàn mới mở ở gần trường mình nên bữ...      1
# 6907   10  Trà Sữa Dưa Lưới y như gu mình thích :))) Tuy ...      1
# 6908  6.8  Fan cuồng mì cay ở đây,mì bò kim chi cực...      1
#
# [11487 rows x 3 columns]

# %% [markdown]
# # Tiền xử lý

# %%
# !pip install underthesea
# Out:
# Requirement already satisfied: underthesea in c:\users\anhdu\anaconda3\envs\cs338\lib\site-packages (6.3.0)
# Requirement already satisfied: Click>=6.0 in c:\users\anhdu\anaconda3\envs\cs338\lib\site-packages (from underthesea) (8.1.3)
# Requirement already satisfied: python-crfsuite>=0.9.6 in c:\users\anhdu\anaconda3\envs\cs338\lib\site-packages (from underthesea) (0.9.9)
# Requirement already satisfied: nltk in c:\users\anhdu\anaconda3\envs\cs338\lib\site-packages (from underthesea) (3.8.1)
# Requirement already satisfied: tqdm in c:\users\anhdu\anaconda3\envs\cs338\lib\site-packages (from underthesea) (4.65.0)
# Requirement already satisfied: requests in c:\users\anhdu\anaconda3\envs\cs338\lib\site-packages (from underthesea) (2.28.1)
# Requirement already satisfied: joblib in c:\users\anhdu\anaconda3\envs\cs338\lib\site-packages (from underthesea) (1.1.1)
# Requirement already satisfied: scikit-learn in c:\users\anhdu\anaconda3\envs\cs338\lib\site-packages (from underthesea) (1.2.2)
# Requirement already satisfied: PyYAML in c:\users\anhdu\anaconda3\envs\cs338\lib\site-packages (from underthesea) (6.0)
# Requirement already satisfied: underthesea-core==1.0.4 in c:\users\anhdu\anaconda3\envs\cs338\lib\site-packages (from underthesea) (1.0.4)
# Requirement already satisfied: colorama in c:\users\anhdu\anaconda3\envs\cs338\lib\site-packages (from Click>=6.0->underthesea) (0.4.6)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\anhdu\anaconda3\envs\cs338\lib\site-packages (from nltk->underthesea) (2023.6.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\anhdu\anaconda3\envs\cs338\lib\site-packages (from requests->underthesea) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anhdu\anaconda3\envs\cs338\lib\site-packages (from requests->underthesea) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\anhdu\anaconda3\envs\cs338\lib\site-packages (from requests->underthesea) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anhdu\anaconda3\envs\cs338\lib\site-packages (from requests->underthesea) (2023.5.7)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\anhdu\anaconda3\envs\cs338\lib\site-packages (from scikit-learn->underthesea) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\anhdu\anaconda3\envs\cs338\lib\site-packages (from scikit-learn->underthesea) (1.10.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\anhdu\anaconda3\envs\cs338\lib\site-packages (from scikit-learn->underthesea) (2.2.0)

# %%
import regex as re
import underthesea

# %% [markdown]
# ## 1. Xoá HTML tag

# %%
def remove_html(text):
  return re.sub(r'<[^>]*>', '', text)

print(remove_html("<h1>Title</h1>"))
# Out:
# Title

# %% [markdown]
# ## 2. Đánh dấu spam URL

# %%
def check_url(text):
    pattern = re.compile(r'(http|https)://[^\s]+')
    match = pattern.search(text)
    if match:
        return True
    else:
        return False

# %%
data.drop(data[data['Review'].apply(check_url)].index, inplace=True)
data.shape
# Out:
# (11481, 3)

# %% [markdown]
# ## 3 Chuẩn hoá Unicode và dấu câu

# %%
from underthesea import text_normalize

uniChars = "àáảãạâầấẩẫậăằắẳẵặèéẻẽẹêềếểễệđìíỉĩịòóỏõọôồốổỗộơờớởỡợùúủũụưừứửữựỳýỷỹỵÀÁẢÃẠÂẦẤẨẪẬĂẰẮẲẴẶÈÉẺẼẸÊỀẾỂỄỆĐÌÍỈĨỊÒÓỎÕỌÔỒỐỔỖỘƠỜỚỞỠỢÙÚỦŨỤƯỪỨỬỮỰỲÝỶỸỴÂĂĐÔƠƯ"
unsignChars = "aaaaaaaaaaaaaaaaaeeeeeeeeeeediiiiiooooooooooooooooouuuuuuuuuuuyyyyyAAAAAAAAAAAAAAAAAEEEEEEEEEEEDIIIOOOOOOOOOOOOOOOOOOOUUUUUUUUUUUYYYYYAADOOU"

# Hàm tạo dict để convert định dạng cũ sang định dạng mới
def loaddicchar():
  dic = {}
  char1252 = 'à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ'.split('|')
  charutf8 = "à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ".split('|')
  for i in range(len(char1252)):
      dic[char1252[i]] = charutf8[i]
  return dic

dicchar = loaddicchar()

# Chuẩn hóa Unicode và dấu câu
def convert_unicode(txt):
    txt = re.sub(
        r'à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ',
        lambda x: dicchar[x.group()], txt)
    return text_normalize(txt)

print(convert_unicode("Ðảm baỏ chất lựơng phòng thí nghịêm hoá học"))
# Out:
# Đảm bảo chất lượng phòng thí nghiệm hóa học

# %% [markdown]
# ## 4. Đưa về dạng viết thường

# %%
def to_lower_case(sentence):
    sentence = sentence.lower()
    return sentence

print(to_lower_case('Tôi là dân IT!'))
# Out:
# tôi là dân it!

# %% [markdown]
# ## 5. Xoá các ký tự không cần thiết

# %%
def remove_unnecessary_charactor(document):
    # xóa các ký tự đặc biệt, emoji
    document = re.sub(r'[^\s\wáàảãạăắằẳẵặâấầẩẫậéèẻẽẹêếềểễệóòỏõọôốồổỗộơớờởỡợíìỉĩịúùủũụưứừửữựýỳỷỹỵđ_]',' ',document)
    # xóa kí tự chứa số
    document = re.sub(r'\w*\d\w*', '', document).strip()
    # xóa khoảng trắng thừa
    document = re.sub(r'\s+', ' ', document).strip()
    return document

document = 'Biết 1505 là gì không? 😆'
remove_unnecessary_charactor(document)
# Out:
# 'Biết là gì không'

# %% [markdown]
# ## 6. Chuẩn hoá những từ lặp âm tiết

# %%
def remove_duplicate_characters(text):
    pattern = re.compile(r'(\w)\1{2,}')
    text = pattern.sub(r'\1', text)
    return text

print(remove_duplicate_characters("Trà sữa ngon nhân viên bán hàng nhiệt tình! Likeeeeeee!"))
# Out:
# Trà sữa ngon nhân viên bán hàng nhiệt tình! Like!

# %% [markdown]
# ## 7. Chuẩn hoá viết tắt

# %%
import re
# Đọc các cặp giá trị từ file văn bản
replacements = {}
with open('abbreviations.txt', 'r') as file:
    for line in file:
        key, value = re.split(':', line, maxsplit=1)
        replacements[key] = value.strip()

def abbreviate(text):
    # Thay thế các giá trị trong chuỗi
    for key, value in replacements.items():
        text = re.sub(r'\b{}\b'.format(key), value, text)
    return(text)

# %%
text = "tôi hong iu k thick cá"
print(abbreviate(text))
# Out:
# tôi không yêu không thích cá

# %% [markdown]
# ## Tổng hợp 1

# %%
def text_preprocessing1(document):
  document = remove_html(document)
  document = convert_unicode(document)
  document = to_lower_case(document)
  document = remove_unnecessary_charactor(document)
  document = remove_duplicate_characters(document)
  document = re.sub(r'\s+', ' ', document).strip() # xóa khoảng trắng thừa
  document = abbreviate(document)
  return document

text_preprocessing1('theo nghị định đã ban hànhhhhh, người dân cần ở trong nhà đến hết ngày 16/9.')
# Out:
# 'theo nghị định đã ban hành người dân cần ở trong nhà đến hết ngày'

# %%
data["Preprocess_Review"] = data["Review"].apply(lambda x: text_preprocessing1(x))
data
# Out:
#      Rate                                             Review  Label  \
# 0     4.0  Mình thề là mình ko thể cảm nổi đồ ăn ở aeon m...     -1
# 1     3.8  Đôi khi thèm lên là bất chấp nắng nóng phi Và ...     -1
# 2     3.8  Ngõ treo biển cafe trứng đúng kiểu phố cổ hà n...     -1
# 3     3.8  Mình thấy địa chỉ cafe Giảng ở Nguyễn Hữu Huân...     -1
# 4     2.2  Mình là người Hà Nội và cũng cực kỳ khó tính t...     -1
# ...   ...                                                ...    ...
# 6904  9.0  Mình là khách hàng thường xuyên của quán, có t...      1
# 6905  7.2  Mình mới đến quán 1 lần và cảm thấy quán khá d...      1
# 6906  8.0  Quán ăn đồ Hàn mới mở ở gần trường mình nên bữ...      1
# 6907   10  Trà Sữa Dưa Lưới y như gu mình thích :))) Tuy ...      1
# 6908  6.8  Fan cuồng mì cay ở đây,mì bò kim chi cực...      1
#
#                                       Preprocess_Review
# 0     mình thề là mình không thể cảm nổi đồ ăn ở aeo...
# 1     đôi khi thèm lên là bất chấp nắng nóng phi và ...
# 2     ngõ treo biển cafe trứng đúng kiểu phố cổ hà n...
# 3     mình thấy địa chỉ cafe giảng ở nguyễn hữu huân...
# 4     mình là người hà nội và cũng cực kỳ khó tính t...
# ...                                                 ...
# 6904  mình là khách hàng thường xuyên của quán có tu...
# 6905  mình mới đến quán lần và cảm thấy quán khá dễ ...
# 6906  quán ăn đồ hàn mới mở ở gần trường mình nên bữ...
# 6907  trà sữa dưa lưới y như gu mình thích tuy vẫn c...
# 6908  fan cuồng mì cay ở đây mì bò kim chi cực ngon ...
#
# [11481 rows x 4 columns]

# %% [markdown]
# ## 8. Tách từ tiếng Việt

# %%
from underthesea import word_tokenize

sentence = 'Xin chào, rất vui được làm quen, tôi đến từ đất nước Việt Nam!'
print(word_tokenize(sentence))
print(word_tokenize(sentence, format='text'))
# Out:
# ['Xin', 'chào', ',', 'rất', 'vui', 'được', 'làm quen', ',', 'tôi', 'đến', 'từ', 'đất nước', 'Việt Nam', '!']
# Xin chào , rất vui được làm_quen , tôi đến từ đất_nước Việt_Nam !

# %% [markdown]
# ## 9. Loại bỏ stopword

# %% [markdown]
# Stopword là những từ thường xuyên xuất hiện trong văn nói, văn viết và không có quá nhiều ý nghĩa, đặc trưng cho bài toán phân loại cảm xúc trong câu. Ví dụ về stopword như: là, rằng, theo, thì, đó,...

# %% [markdown]
# ### 9.1. Xử lý với stopwords đã tổng hợp

# %%
# %pwd
# Out:
# 'd:\\UIT\\Nam3_ky2\\ML\\CS114\\Final_project\\code'

# %%
stopwords = open('stopword.txt')
stopwords = stopwords.readlines()
stopwords = [x.strip() for x in stopwords]

# %%
len(stopwords)
# Out:
# 1814

# %%
def remove_stopwords(document):
  words = document.split(' ')
  res = list()
  for word in words:
    if word not in stopwords:
      res.append(word)

  return ' '.join(res)

print(text_preprocessing1('Nhân viên hơi thái_độ Giá cũng cao hơn các chỗ khác'))
print(remove_stopwords(text_preprocessing1('Nhân viên hơi thái_độ Giá cũng cao hơn các chỗ')))
# Out:
# nhân viên hơi thái_độ giá cũng cao hơn các chỗ khác
# nhân viên hơi thái_độ giá cao hơn chỗ

# %% [markdown]
# # Tổng hợp 2

# %%
def text_preprocessing2(document):
  document = word_tokenize(document, format='text')
  document = remove_stopwords(document)
  return document

# %%
data["Preprocess_Review"] = data["Preprocess_Review"].apply(lambda x: text_preprocessing2(x))
data
# Out:
#      Rate                                             Review  Label  \
# 0     4.0  Mình thề là mình ko thể cảm nổi đồ ăn ở aeon m...     -1
# 1     3.8  Đôi khi thèm lên là bất chấp nắng nóng phi Và ...     -1
# 2     3.8  Ngõ treo biển cafe trứng đúng kiểu phố cổ hà n...     -1
# 3     3.8  Mình thấy địa chỉ cafe Giảng ở Nguyễn Hữu Huân...     -1
# 4     2.2  Mình là người Hà Nội và cũng cực kỳ khó tính t...     -1
# ...   ...                                                ...    ...
# 6904  9.0  Mình là khách hàng thường xuyên của quán, có t...      1
# 6905  7.2  Mình mới đến quán 1 lần và cảm thấy quán khá d...      1
# 6906  8.0  Quán ăn đồ Hàn mới mở ở gần trường mình nên bữ...      1
# 6907   10  Trà Sữa Dưa Lưới y như gu mình thích :))) Tuy ...      1
# 6908  6.8  Fan cuồng mì cay ở đây,mì bò kim chi cực...      1
#
#                                       Preprocess_Review
# 0     thề không_thể cảm nổi đồ ăn aeon mall ăn food ...
# 1     đôi thèm bất_chấp nắng nóng phi đóng_đô quầy f...
# 2     ngõ treo biển cafe trứng phố cổ hà_nội sâu nhỏ...
# 3     địa_chỉ cafe giảng nguyễn_hữu_huân ngon hồi cò...
# 4     hà_nội cực_kỳ khó_tính ăn phố gần cafe cũ giản...
# ...                                                 ...
# 6904  khách_hàng thường_xuyên tuần ăn thích nhất súp...
# 6905  khá dễ tìm thân_thiện đồ ăn_theo phong_cách hà...
# 6906  ăn đồ hàn gần trường nên bữa thèm nên quất nằm...
# 6907  dưa lưới y_như gu thích tuy vẫn dưa lưới nhưng...
# 6908  fan cuồng mì cay mì kim_chi cực ngon máy_lạnh ...
#
# [11481 rows x 4 columns]

# %% [markdown]
# ## 10. Bỏ các giá trị NaN, giá trị rỗng, lặp lại

# %%
# data.drop_duplicates(inplace=True)
# data

# %%
data.isna().sum()
# Out:
# Rate                 0
# Review               0
# Label                0
# Preprocess_Review    0
# dtype: int64

# %% [markdown]
# ## Lưu dữ liệu đã tiền xử lý

# %%
data.to_excel("../dataset/final_data.1.xlsx", index=False)
